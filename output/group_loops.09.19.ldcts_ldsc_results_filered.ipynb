# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
from statsmodels.stats.multitest import multipletests
from scipy.cluster.hierarchy import linkage, leaves_list

# %%
# PARAMETERS
run_id="group_loops.09.19.ldcts"

# %%
# Parameters
run_id = "group_loops.09.19.ldcts"

# %%
selected_traits = {
    "Bellenguez.NatGenet.2022.Alzheimers_Disease_Dementia_" : "Alzheimers Disease and Dementia", 
    "Nalls.LancetNeurol.2019.Parkinsons_disease_" : "Parkinson's Disease", 
    "PGC.Nature.2014.Schizophrenia_" : "Schizophrenia", 
    "Wray.biorxiv.2018.Major_Depressive_Disorder_" : "Major Depressive Disorder", 
    "Demontis.NatGenet.2019.Attention_Deficit_Hyperactivity_Disorder_" : "ADHD", 
    "Mullins.NatGenet.2021.Bipolar_Disorder_" : "Bipolar Disorder", 
    "Grove.NatGenet.2019.Autism_Spectrum_Disorder_" : "Autism Spectrum Disorder", 
    "Jansen.2019.NatGenet.Insomnia_" : "Insomnia", 
    "PGC.MolPsychiatry.2017.Obsessive_Compulsive_Disorder_" : "Obsessive Compulsive Disorder", 
    "Deary.MolPsychiatry.2017.Tiredness_" : "Tiredness", 
    "IMSGC.Science.2019.Multiple_sclerosis_" : "Multiple Sclerosis", 
    "Luciano.NatGenet.2017.Neuroticism_" : "Neuroticism", 
    "Okbay.Nature.2016.Educational_Attainment_" : "Educational Attainment", 
    "Palmer.MolPsych.2021.problematic_opioid_use_" : "Problematic Opioid Use", 
    "Savage.NatGenet.2018.Intelligence_" : "Intelligence", 
    "vanRheenen.NatGenet.2016.Amyotrophic_Lateral_Sclerosis_" : "Amyotrophic Lateral Sclerosis", 
    "Barban.NatGenet.2016.Age_First_Birth_" : "Age at First Birth", 
    "Chiou.Nature.2021.Type_1_diabetes_" : "Type 1 Diabetes", 
    "Watson.2018.NatGenet.Anorexia_Nervosa_" : "Anorexia Nervosa"
}

# %%
ldsc_results=f'/anvil/projects/x-mcb130189/rwang22/bican/ldsc/output/{run_id}'
directory = Path(ldsc_results)
dfs = {}

for file in directory.glob(f'*.cell_type_results.txt'):
    cur = pd.read_csv(file, sep = "\t")
    stripped = file.stem.replace(f'_.cell_type_results', "")
    cur["Trait"] = stripped
    dfs[stripped] = cur

# %%
combined_df = pd.concat(dfs.values(), ignore_index=True)
combined_df["-log10(pval)"] = -np.log10(combined_df["Coefficient_P_value"])
combined_df["Trait"] = combined_df["Trait"].str.replace(f'{run_id}.cell_type_results', "")
combined_df = combined_df[combined_df["Trait"].isin(selected_traits.keys())] # only predetermined selected traits
combined_df.head()
# Out:
#             Name   Coefficient  Coefficient_std_error  Coefficient_P_value  \
# 660   Lymphocyte  9.802979e-09           3.196895e-09             0.001083
# 661  Microglia-3  5.052252e-09           2.085195e-09             0.007698
# 662  Microglia-2  3.898444e-09           1.774327e-09             0.014005
# 663  Microglia-1  2.015061e-09           1.582615e-09             0.101465
# 664         Endo  1.119049e-09           1.528991e-09             0.232119
#
#                                   Trait  -log10(pval)
# 660  Chiou.Nature.2021.Type_1_diabetes_      2.965274
# 661  Chiou.Nature.2021.Type_1_diabetes_      2.113609
# 662  Chiou.Nature.2021.Type_1_diabetes_      1.853709
# 663  Chiou.Nature.2021.Type_1_diabetes_      0.993684
# 664  Chiou.Nature.2021.Type_1_diabetes_      0.634290

# %%
# Perform FDR correction using Benjamini-Hochberg procedure
rejected, q_values, _, _ = multipletests(combined_df["Coefficient_P_value"], alpha=0.05, method='fdr_bh')
combined_df["FDR_BH_corrected"] = q_values

# %%
# calculate the FDR p value threshold 
# https://www.r-bloggers.com/2023/07/the-benjamini-hochberg-procedure-fdr-and-p-value-adjusted-explained/

def fdr_bh_adj(df):
    tmp = combined_df.copy()
    tmp["rank"] =  combined_df['Coefficient_P_value'].rank()
    num_tests = len(tmp)
    tmp["adj_pval"] = (num_tests * tmp["Coefficient_P_value"]) / tmp["rank"]

    return tmp

# %%
tmp = fdr_bh_adj(combined_df)
# Align indices before comparison
fdr_bh_corrected = combined_df["FDR_BH_corrected"]
adj_pval = tmp["adj_pval"]

print(fdr_bh_corrected.sort_values())
# Out:
# 6301    3.542999e-08
# 6300    3.542999e-08
# 2460    7.596221e-08
# 2461    1.422445e-07
# 5220    2.254122e-07
#             ...
# 2985    9.993469e-01
# 2984    9.993469e-01
# 2992    9.993469e-01
# 6479    9.993469e-01
# 2999    9.995586e-01
# Name: FDR_BH_corrected, Length: 1140, dtype: float64

# %%
print(adj_pval.sort_values())
# Out:
# 6301    3.542999e-08
# 6300    4.503309e-08
# 2460    7.596221e-08
# 2461    1.422445e-07
# 5220    2.254122e-07
#             ...
# 2987    1.004025e+00
# 1018    1.004278e+00
# 1799    1.004302e+00
# 2986    1.004343e+00
# 2985    1.004505e+00
# Name: adj_pval, Length: 1140, dtype: float64

# %%
# plot the distribution of p values 
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# First plot
sns.histplot(combined_df["FDR_BH_corrected"], kde=True, ax=axes[0])
axes[0].set_title("FDR_BH_corrected")

# Second plot
sns.histplot(combined_df["Coefficient_P_value"], kde=True, ax=axes[1])
axes[1].set_title("P value")

plt.tight_layout()
plt.show()

# %%
modified_df = combined_df.drop(['Coefficient', 'Coefficient_std_error', 'Coefficient_P_value', 'FDR_BH_corrected'], axis=1)
modified_df = modified_df.pivot(index="Name", columns="Trait", values="-log10(pval)").reset_index()
modified_df = modified_df.set_index("Name")
modified_df.head()
# Out:
# Trait               Barban.NatGenet.2016.Age_First_Birth_  \
# Name
# ACx_MEIS2_GABA                                   2.190354
# AMY-SLEA-BNST_GABA                               0.208865
# Astrocyte-1                                      0.150860
# Astrocyte-2                                      0.057414
# Astrocyte-3                                      0.044704
#
# Trait               Bellenguez.NatGenet.2022.Alzheimers_Disease_Dementia_  \
# Name
# ACx_MEIS2_GABA                                               0.056450
# AMY-SLEA-BNST_GABA                                           0.334406
# Astrocyte-1                                                  0.041978
# Astrocyte-2                                                  0.006987
# Astrocyte-3                                                  0.036385
#
# Trait               Chiou.Nature.2021.Type_1_diabetes_  \
# Name
# ACx_MEIS2_GABA                                0.076731
# AMY-SLEA-BNST_GABA                            0.123215
# Astrocyte-1                                   0.159358
# Astrocyte-2                                   0.126486
# Astrocyte-3                                   0.045567
#
# Trait               Deary.MolPsychiatry.2017.Tiredness_  \
# Name
# ACx_MEIS2_GABA                                 0.885502
# AMY-SLEA-BNST_GABA                             1.530218
# Astrocyte-1                                    0.183489
# Astrocyte-2                                    0.153248
# Astrocyte-3                                    0.298489
#
# Trait               Demontis.NatGenet.2019.Attention_Deficit_Hyperactivity_Disorder_  \
# Name
# ACx_MEIS2_GABA                                               0.243539
# AMY-SLEA-BNST_GABA                                           0.681987
# Astrocyte-1                                                  0.408987
# Astrocyte-2                                                  0.047067
# Astrocyte-3                                                  0.477166
#
# Trait               Grove.NatGenet.2019.Autism_Spectrum_Disorder_  \
# Name
# ACx_MEIS2_GABA                                           0.784417
# AMY-SLEA-BNST_GABA                                       0.612026
# Astrocyte-1                                              0.348100
# Astrocyte-2                                              0.518545
# Astrocyte-3                                              1.253385
#
# Trait               IMSGC.Science.2019.Multiple_sclerosis_  \
# Name
# ACx_MEIS2_GABA                                    0.002058
# AMY-SLEA-BNST_GABA                                0.033047
# Astrocyte-1                                       0.131881
# Astrocyte-2                                       0.310969
# Astrocyte-3                                       0.486428
#
# Trait               Jansen.2019.NatGenet.Insomnia_  \
# Name
# ACx_MEIS2_GABA                            0.742305
# AMY-SLEA-BNST_GABA                        0.803089
# Astrocyte-1                               0.100734
# Astrocyte-2                               0.188749
# Astrocyte-3                               0.737213
#
# Trait               Luciano.NatGenet.2017.Neuroticism_  \
# Name
# ACx_MEIS2_GABA                                3.718518
# AMY-SLEA-BNST_GABA                            3.457479
# Astrocyte-1                                   0.749627
# Astrocyte-2                                   1.097376
# Astrocyte-3                                   0.953350
#
# Trait               Mullins.NatGenet.2021.Bipolar_Disorder_  \
# Name
# ACx_MEIS2_GABA                                     6.789038
# AMY-SLEA-BNST_GABA                                 2.053010
# Astrocyte-1                                        1.518950
# Astrocyte-2                                        1.603990
# Astrocyte-3                                        2.425056
#
# Trait               Nalls.LancetNeurol.2019.Parkinsons_disease_  \
# Name
# ACx_MEIS2_GABA                                         0.098206
# AMY-SLEA-BNST_GABA                                     1.738616
# Astrocyte-1                                            0.528999
# Astrocyte-2                                            0.536235
# Astrocyte-3                                            1.088782
#
# Trait               Okbay.Nature.2016.Educational_Attainment_  \
# Name
# ACx_MEIS2_GABA                                       5.883819
# AMY-SLEA-BNST_GABA                                   2.735033
# Astrocyte-1                                          0.482228
# Astrocyte-2                                          0.788544
# Astrocyte-3                                          1.307425
#
# Trait               PGC.MolPsychiatry.2017.Obsessive_Compulsive_Disorder_  \
# Name
# ACx_MEIS2_GABA                                               0.410245
# AMY-SLEA-BNST_GABA                                           0.825038
# Astrocyte-1                                                  0.414407
# Astrocyte-2                                                  0.216887
# Astrocyte-3                                                  0.320419
#
# Trait               PGC.Nature.2014.Schizophrenia_  \
# Name
# ACx_MEIS2_GABA                            7.198381
# AMY-SLEA-BNST_GABA                        3.714389
# Astrocyte-1                               1.551923
# Astrocyte-2                               1.816522
# Astrocyte-3                               2.058646
#
# Trait               Palmer.MolPsych.2021.problematic_opioid_use_  \
# Name
# ACx_MEIS2_GABA                                          0.077921
# AMY-SLEA-BNST_GABA                                      0.281343
# Astrocyte-1                                             0.098772
# Astrocyte-2                                             0.254517
# Astrocyte-3                                             0.153428
#
# Trait               Savage.NatGenet.2018.Intelligence_  \
# Name
# ACx_MEIS2_GABA                                5.880731
# AMY-SLEA-BNST_GABA                            3.375620
# Astrocyte-1                                   1.183288
# Astrocyte-2                                   0.825699
# Astrocyte-3                                   0.805134
#
# Trait               Watson.2018.NatGenet.Anorexia_Nervosa_  \
# Name
# ACx_MEIS2_GABA                                    0.429962
# AMY-SLEA-BNST_GABA                                0.051988
# Astrocyte-1                                       0.414855
# Astrocyte-2                                       0.253742
# Astrocyte-3                                       0.422253
#
# Trait               Wray.biorxiv.2018.Major_Depressive_Disorder_  \
# Name
# ACx_MEIS2_GABA                                          2.400906
# AMY-SLEA-BNST_GABA                                      1.920881
# Astrocyte-1                                             0.790823
# Astrocyte-2                                             0.268711
# Astrocyte-3                                             0.622483
#
# Trait               vanRheenen.NatGenet.2016.Amyotrophic_Lateral_Sclerosis_
# Name
# ACx_MEIS2_GABA                                               0.644567
# AMY-SLEA-BNST_GABA                                           0.072798
# Astrocyte-1                                                  0.146807
# Astrocyte-2                                                  0.146869
# Astrocyte-3                                                  0.160486

# %%
fdr_modified_df = combined_df.drop(['Coefficient', 'Coefficient_std_error', 'Coefficient_P_value', '-log10(pval)'], axis=1)
fdr_modified_df = fdr_modified_df.pivot(index="Name", columns="Trait", values="FDR_BH_corrected").reset_index()
fdr_modified_df = fdr_modified_df.set_index("Name")
fdr_modified_df.head()
# Out:
# Trait               Barban.NatGenet.2016.Age_First_Birth_  \
# Name
# ACx_MEIS2_GABA                                   0.042026
# AMY-SLEA-BNST_GABA                               0.824278
# Astrocyte-1                                      0.878922
# Astrocyte-2                                      0.965052
# Astrocyte-3                                      0.970333
#
# Trait               Bellenguez.NatGenet.2022.Alzheimers_Disease_Dementia_  \
# Name
# ACx_MEIS2_GABA                                               0.965330
# AMY-SLEA-BNST_GABA                                           0.706608
# Astrocyte-1                                                  0.974545
# Astrocyte-2                                                  0.999347
# Astrocyte-3                                                  0.977968
#
# Trait               Chiou.Nature.2021.Type_1_diabetes_  \
# Name
# ACx_MEIS2_GABA                                0.943114
# AMY-SLEA-BNST_GABA                            0.898794
# Astrocyte-1                                   0.867835
# Astrocyte-2                                   0.896985
# Astrocyte-3                                   0.970216
#
# Trait               Deary.MolPsychiatry.2017.Tiredness_  \
# Name
# ACx_MEIS2_GABA                                 0.334965
# AMY-SLEA-BNST_GABA                             0.129334
# Astrocyte-1                                    0.843025
# Astrocyte-2                                    0.875459
# Astrocyte-3                                    0.736948
#
# Trait               Demontis.NatGenet.2019.Attention_Deficit_Hyperactivity_Disorder_  \
# Name
# ACx_MEIS2_GABA                                               0.791825
# AMY-SLEA-BNST_GABA                                           0.448190
# Astrocyte-1                                                  0.650874
# Astrocyte-2                                                  0.970216
# Astrocyte-3                                                  0.595549
#
# Trait               Grove.NatGenet.2019.Autism_Spectrum_Disorder_  \
# Name
# ACx_MEIS2_GABA                                           0.388545
# AMY-SLEA-BNST_GABA                                       0.489436
# Astrocyte-1                                              0.694448
# Astrocyte-2                                              0.563507
# Astrocyte-3                                              0.198160
#
# Trait               IMSGC.Science.2019.Multiple_sclerosis_  \
# Name
# ACx_MEIS2_GABA                                    0.999347
# AMY-SLEA-BNST_GABA                                0.980420
# Astrocyte-1                                       0.893838
# Astrocyte-2                                       0.725168
# Astrocyte-3                                       0.586661
#
# Trait               Jansen.2019.NatGenet.Insomnia_  \
# Name
# ACx_MEIS2_GABA                            0.414353
# AMY-SLEA-BNST_GABA                        0.378475
# Astrocyte-1                               0.919068
# Astrocyte-2                               0.840900
# Astrocyte-3                               0.417939
#
# Trait               Luciano.NatGenet.2017.Neuroticism_  \
# Name
# ACx_MEIS2_GABA                                0.002717
# AMY-SLEA-BNST_GABA                            0.004230
# Astrocyte-1                                   0.410725
# Astrocyte-2                                   0.253766
# Astrocyte-3                                   0.302929
#
# Trait               Mullins.NatGenet.2021.Bipolar_Disorder_  \
# Name
# ACx_MEIS2_GABA                                     0.000006
# AMY-SLEA-BNST_GABA                                 0.053671
# Astrocyte-1                                        0.132225
# Astrocyte-2                                        0.113042
# Astrocyte-3                                        0.027216
#
# Trait               Nalls.LancetNeurol.2019.Parkinsons_disease_  \
# Name
# ACx_MEIS2_GABA                                         0.919574
# AMY-SLEA-BNST_GABA                                     0.087440
# Astrocyte-1                                            0.554628
# Astrocyte-2                                            0.549077
# Astrocyte-3                                            0.255283
#
# Trait               Okbay.Nature.2016.Educational_Attainment_  \
# Name
# ACx_MEIS2_GABA                                       0.000036
# AMY-SLEA-BNST_GABA                                   0.015205
# Astrocyte-1                                          0.591429
# Astrocyte-2                                          0.385670
# Astrocyte-3                                          0.185785
#
# Trait               PGC.MolPsychiatry.2017.Obsessive_Compulsive_Disorder_  \
# Name
# ACx_MEIS2_GABA                                               0.650514
# AMY-SLEA-BNST_GABA                                           0.366787
# Astrocyte-1                                                  0.645638
# Astrocyte-2                                                  0.814910
# Astrocyte-3                                                  0.716310
#
# Trait               PGC.Nature.2014.Schizophrenia_  \
# Name
# ACx_MEIS2_GABA                            0.000003
# AMY-SLEA-BNST_GABA                        0.002717
# Astrocyte-1                               0.123983
# Astrocyte-2                               0.080005
# Astrocyte-3                               0.053262
#
# Trait               Palmer.MolPsych.2021.problematic_opioid_use_  \
# Name
# ACx_MEIS2_GABA                                          0.942628
# AMY-SLEA-BNST_GABA                                      0.754979
# Astrocyte-1                                             0.919574
# Astrocyte-2                                             0.781326
# Astrocyte-3                                             0.875459
#
# Trait               Savage.NatGenet.2018.Intelligence_  \
# Name
# ACx_MEIS2_GABA                                0.000036
# AMY-SLEA-BNST_GABA                            0.004849
# Astrocyte-1                                   0.223137
# Astrocyte-2                                   0.366787
# Astrocyte-3                                   0.377777
#
# Trait               Watson.2018.NatGenet.Anorexia_Nervosa_  \
# Name
# ACx_MEIS2_GABA                                    0.634112
# AMY-SLEA-BNST_GABA                                0.968119
# Astrocyte-1                                       0.645638
# Astrocyte-2                                       0.781757
# Astrocyte-3                                       0.640674
#
# Trait               Wray.biorxiv.2018.Major_Depressive_Disorder_  \
# Name
# ACx_MEIS2_GABA                                          0.028130
# AMY-SLEA-BNST_GABA                                      0.067380
# Astrocyte-1                                             0.384450
# Astrocyte-2                                             0.766587
# Astrocyte-3                                             0.488160
#
# Trait               vanRheenen.NatGenet.2016.Amyotrophic_Lateral_Sclerosis_
# Name
# ACx_MEIS2_GABA                                               0.475050
# AMY-SLEA-BNST_GABA                                           0.946090
# Astrocyte-1                                                  0.881548
# Astrocyte-2                                                  0.881548
# Astrocyte-3                                                  0.866673

# %%
g = sns.clustermap(modified_df, cmap='coolwarm', figsize=(25, 25))

plt.show()
# g.savefig(f'output/{run_id}_filtered.pdf')

# %%
def pval_to_star(p):
    if p < 1e-7:
        return '***'
    elif p < 1e-5:
        return '**'
    elif p < 0.05:
        return '*'
    else:
        return ''

# %%
# Cluster rows
linkage_rows = linkage(modified_df.values, method="average", metric="euclidean")
row_order = leaves_list(linkage_rows)

# Cluster columns
linkage_cols = linkage(modified_df.values.T, method="average", metric="euclidean")
col_order = leaves_list(linkage_cols)

modified_df = modified_df.iloc[row_order, col_order].rename(columns = selected_traits)
fdr_modified_df = fdr_modified_df.iloc[row_order, col_order].rename(columns = selected_traits)

# %%
fdr_modified_df = fdr_modified_df.reindex(
    index=modified_df.index,    # same row order as df
    columns=modified_df.columns # same column order as df
)

# %%
cols_to_keep = fdr_modified_df.loc[:, (fdr_modified_df < 0.05).any()].columns
cols_to_keep
# Out:
# Index(['Autism Spectrum Disorder', 'Age at First Birth', 'Parkinson's Disease',
#        'Obsessive Compulsive Disorder', 'Alzheimers Disease and Dementia',
#        'Type 1 Diabetes', 'Multiple Sclerosis', 'Major Depressive Disorder',
#        'Tiredness', 'Insomnia', 'Schizophrenia', 'Intelligence',
#        'Bipolar Disorder', 'Neuroticism', 'Educational Attainment'],
#       dtype='object', name='Trait')

# %%
# stars = fdr_modified_df[cols_to_keep].applymap(pval_to_star)

# # Plot heatmap with annotations
# plt.figure(figsize=(25, 15))
# sns.heatmap(modified_df[cols_to_keep], annot=stars, fmt='', cmap='coolwarm')
# plt.title("-log10(pval) with FDR corrected p value stars")
# plt.tight_layout()
# plt.savefig(f'output/{run_id}_filtered_FDR_corrected.pdf')
# plt.show()

# %%
import os
metadata = pd.read_csv(os.path.expanduser("~/Projects/BG/clustering/100kb/annotations.tsv"),sep='\t',index_col=0)
keep_cells=metadata.loc[~ (metadata['Group'].isin(['doublet','Glut','Unk','Low quality cells']))].index.tolist() #,
metadata=metadata.loc[keep_cells]
df_cols = metadata.loc[:,['Group','Subclass','Class','Neighborhood']].drop_duplicates().set_index('Group')
df_cols.sort_values(['Neighborhood','Class','Subclass','Group'],inplace=True)
df_cols.head()
# Out:
#                       Subclass     Class    Neighborhood
# Group
# BF SKOR1 Glut           F Glut  F M Glut  Glut Sero Dopa
# STH PVALB-PITX2 Glut    F Glut  F M Glut  Glut Sero Dopa
# VTR-HTH Glut          F M Glut  F M Glut  Glut Sero Dopa
# SN SOX6 Dopa            M Dopa    M Dopa  Glut Sero Dopa
# SN-VTR CALB1 Dopa       M Dopa    M Dopa  Glut Sero Dopa

# %%
import matplotlib as mpl
mpl.style.use('default')
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'Arial'
mpl.rcParams['figure.dpi'] = 80
mpl.rcParams['savefig.dpi']=300

# %%
vmax=modified_df.loc[:,cols_to_keep].max().max()
print(vmax)
# Out:
# 10.403373106635712

# %%
-np.log10(0.05)
# Out:
# 1.3010299956639813

# %%
# Plot heatmap with annotations
import os

modified_df.index=modified_df.index.to_series().apply(lambda x:x.replace('_',' '))
fdr_modified_df.index=fdr_modified_df.index.to_series().apply(lambda x:x.replace('_',' '))

row_order=[ct for ct in df_cols.index.tolist() if ct in modified_df.index.tolist()]
fig, ax = plt.subplots(figsize=(6.5, 12))
ax=sns.heatmap(modified_df.loc[row_order,cols_to_keep], #annot=fdr_modified_df.loc[row_order,cols_to_keep].applymap(pval_to_star), 
               fmt='', cmap='Reds',cbar_kws={'shrink': 0.4,'fraction':0.1,'aspect':6},
               annot_kws=dict(ha='center',va='center'),vmin=1.3,vmax=vmax,#cbar=False,
              ax=ax)
# plt.title("-log10(pval) with FDR corrected p value stars")
ax.set_title("LDSC on Group loop anchors")
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
cbar = ax.collections[0].colorbar
cbar.set_label("-log10(p-value)", fontsize=10, labelpad=1)
cbar.set_ticks([1.3,3,4,4.85,vmax])
plt.tight_layout()
# plt.savefig(f'{run_id}_filtered_FDR.pdf')
plt.savefig(os.path.expanduser("~/Projects/BG/pseudobulk/DMR/LDSC_plots/Group_loops.pdf"),transparent=True,bbox_inches='tight',dpi=300)
plt.show()
