# %%
import papermill as pm

# %%
# DMR 
runid="hyper_DMRs.08.01.ldcts"
pm.execute_notebook('03.format_output.ipynb',  # input notebook file
            f"output/{runid}_ldsc_results.ipynb",  # output notebook file
            parameters={'run_id' : runid}
)

# %%
runid="hypo_DMRs.07.24.ldcts"
pm.execute_notebook('03.format_output.ipynb',  # input notebook file
            f"output/{runid}_ldsc_results.ipynb",  # output notebook file
            parameters={'run_id' : runid}
)

# %%
# 09/23/25
ids= ["group_loops.09.19.ldcts", "hyper_DMRs.09.19.ldcts", 
      "hypo_DMRs.09.19.ldcts", "subclass_loops.09.19.ldcts"]

for runid in ids:
    pm.execute_notebook('04.format_output.ipynb',  # input notebook file
                f"output/{runid}_ldsc_results.ipynb",  # output notebook file
                parameters={'run_id' : runid}
    )

# %%
# 09/30/25 - dmrs 
ids= ["hyper_DMRs.09.26.ldcts", "hypo_DMRs.09.26.ldcts"]

for runid in ids:
    pm.execute_notebook('04.format_output.ipynb',  # input notebook file
                f"output/{runid}_ldsc_results.ipynb",  # output notebook file
                parameters={'run_id' : runid}
    )

# %%
# 09/30/25 - ct specific dmrs
ids= ["hyper_DMRs.09.26.ldcts", "hypo_DMRs.09.26.ldcts"]

for runid in ids:
    pm.execute_notebook('04.format_output.ipynb',  # input notebook file
                f"output/{runid}_ldsc_results.ipynb",  # output notebook file
                parameters={'run_id' : runid}
    )

# %% [markdown]
# # filtered final prettier ldsc plots

# %%
ids= ["group_loops.09.19.ldcts", "subclass_loops.09.19.ldcts", 
      "hyper_DMRs.09.19.ldcts", "hypo_DMRs.09.19.ldcts"]

for runid in ids:
    pm.execute_notebook('04.format_output_filtered.ipynb',  # input notebook file
                f"output/{runid}_ldsc_results_filered.ipynb",  # output notebook file
                parameters={'run_id' : runid}
    )
# Out:
# ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]

# %%
ids= ["hyper.10.02.ldcts", "hypo.10.02.ldcts"]

for runid in ids:
    pm.execute_notebook('04.format_output_filtered.ipynb',  # input notebook file
                f"output/{runid}_ldsc_results_filered.ipynb",  # output notebook file
                parameters={'run_id' : runid}
    )
# Out:
# ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]

# %%
ids= ["group.msn.hyper.10.14.ldcts", "group.msn.hypo.10.14.ldcts"]

for runid in ids:
    pm.execute_notebook('04.format_output_filtered.ipynb',  # input notebook file
                f"output/{runid}_ldsc_results_filered.ipynb",  # output notebook file
                parameters={'run_id' : runid}
    )
# Out:
# ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]

# %%
# 12.02 
runid = "msn.hypo.12.02.ldcts"
pm.execute_notebook('04.format_output_filtered.ipynb',  # input notebook file
                    f"output/{runid}_ldsc_results_filered.ipynb",  # output notebook file
                    parameters={'run_id' : runid} )

# %%
runid = "msn.hyper.12.02.ldcts"
pm.execute_notebook('04.format_output_filtered.ipynb',  # input notebook file
                    f"output/{runid}_ldsc_results_filered.ipynb",  # output notebook file
                    parameters={'run_id' : runid} )

# %%
runid = "abc-group.12.23.ldcts"
pm.execute_notebook('04.format_output_filtered.ipynb',  # input notebook file
                    f"output/{runid}_ldsc_results_filered.ipynb",  # output notebook file
                    parameters={'run_id' : runid} )
# Out:
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': '9dd49e24',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2025-12-23T23:10:35.659249',
#      'end_time': '2025-12-23T23:10:58.696422',
#      'duration': 23.037173,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2025-12-23T23:10:35.664472Z',
#      'iopub.execute_input': '2025-12-23T23:10:35.664777Z',
#      'iopub.status.idle': '2025-12-23T23:10:58.694935Z',
#      'shell.execute_reply': '2025-12-23T23:10:58.694418Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd\nfrom pathlib import Path\nimport seaborn as sns\nfrom matplotlib import pyplot as plt\nimport numpy as np\nfrom statsmodels.stats.multitest import multipletests\nfrom scipy.cluster.hierarchy import linkage, leaves_list'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': '9bd2d682',
# ...

# %%
runid = "abc-subclass.12.23.ldcts"
pm.execute_notebook('04.format_output_filtered.ipynb',  # input notebook file
                    f"output/{runid}_ldsc_results_filered.ipynb",  # output notebook file
                    parameters={'run_id' : runid} )
# Out:
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': '9dd49e24',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2025-12-23T23:11:23.429607',
#      'end_time': '2025-12-23T23:11:46.872062',
#      'duration': 23.442455,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2025-12-23T23:11:23.435795Z',
#      'iopub.execute_input': '2025-12-23T23:11:23.436304Z',
#      'iopub.status.idle': '2025-12-23T23:11:46.870599Z',
#      'shell.execute_reply': '2025-12-23T23:11:46.870049Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd\nfrom pathlib import Path\nimport seaborn as sns\nfrom matplotlib import pyplot as plt\nimport numpy as np\nfrom statsmodels.stats.multitest import multipletests\nfrom scipy.cluster.hierarchy import linkage, leaves_list'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': '9bd2d682',
# ...
